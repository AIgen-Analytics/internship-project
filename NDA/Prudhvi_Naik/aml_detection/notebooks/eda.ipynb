# %% [markdown]
# # Exploratory Data Analysis - AML Detection

# %% [markdown]
# This notebook performs initial analysis on the raw datasets to understand the distributions, target labels, and dataset schemas.

# %%
import pandas as pd

txn = pd.read_parquet("../data/raw/stg_transactions_features.parquet")
print(txn.info())
print(txn["is_aml"].value_counts())
